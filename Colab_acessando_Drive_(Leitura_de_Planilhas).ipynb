# %% [markdown]
# <a href="https://colab.research.google.com/github/Roberto-Lecher/Analise-de-dados-com-Google-Colab/blob/main/Colab_acessando_Drive_(Leitura_de_Planilhas).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/Teste/
# Out:
# /content/drive/MyDrive/Teste

# %%
import pandas as pd

# %%
df = pd.read_excel('/content/drive/MyDrive/Listagem Computadores.xlsx')
df.head(11)
# Out:
#      COMPUTADORES    Unnamed: 1  Unnamed: 2    Unnamed: 3
# 0              IP       Usuário     Anydesk         Setor
# 1   192.168.0.109           Bia  1479465285       Criação
# 2   192.168.0.164        Daiana   483416516       Criação
# 3    192.168.0.17        Marcos  1983964589       Criação
# 4   192.168.0.236       Giselle   278326358       Criação
# 5    192.168.0.29           Ana  1537955791       Criação
# 6    192.168.0.33        Vivian         NaN       Criação
# 7    192.168.0.32          Joao   811348847  Almoxarifado
# 8    192.168.0.85        Yasmin  1550177489     Expedição
# 9    192.168.0.81  Expedição 01  1175687695     Expedição
# 10   192.168.0.77  Expedição 02   378158347     Expedição

# %%
df.to_excel('/content/drive/MyDrive/Listagem Computadores.xlsx', index=False)

# %%
import os

os.listdir('/content/drive/MyDrive/Teste')
# Out:
# ['Listagem Computadores.xlsx']
